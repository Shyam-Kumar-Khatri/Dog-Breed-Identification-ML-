# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

import cv2
import tensorflow as tf
from tensorflow import keras
from keras import layers
from functools import partial

import warnings
warnings.filterwarnings('ignore')
AUTO = tf.data.experimental.AUTOTUNE

# %%
df = pd.read_csv("./dog-breed-identification/labels.csv")
df.head()
# Out:
#                                  id             breed
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever

# %%
df.shape
# Out:
# (10222, 2)

# %%
df['breed'].nunique()
# Out:
# 120

# %%
plt.figure(figsize=(10, 5))
df['breed'].value_counts().plot.bar()
plt.axis('off')
plt.show()

# %%
df['filepath'] = './dog-breed-identification/train/' + df['id'] + '.jpg'
df.head()
# Out:
#                                  id             breed  \
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever
#
#                                             filepath
# 0  ./dog-breed-identification/train/000bec180eb18...
# 1  ./dog-breed-identification/train/001513dfcb2ff...
# 2  ./dog-breed-identification/train/001cdf01b096e...
# 3  ./dog-breed-identification/train/00214f311d5d2...
# 4  ./dog-breed-identification/train/0021f9ceb3235...

# %%
plt.subplots(figsize=(10, 10))
for i in range(12):
    plt.subplot(4, 3, i+1)

    # Selecting a random image
    # index from the dataframe.
    k = np.random.randint(0, len(df))
    img = cv2.imread(df.loc[k, 'filepath'])
    plt.imshow(img)
    plt.title(df.loc[k, 'breed'])
    plt.axis('off')
plt.show()

# %%
le = LabelEncoder()
df['breed'] = le.fit_transform(df['breed'])
df.head()
# Out:
#                                  id  breed  \
# 0  000bec180eb18c7604dcecc8fe0dba07     19
# 1  001513dfcb2ffafc82cccf4d8bbaba97     37
# 2  001cdf01b096e06d78e9e5112d419397     85
# 3  00214f311d5d2247d5dfe4fe24b2303d     15
# 4  0021f9ceb3235effd7fcde7f7538ed62     49
#
#                                             filepath
# 0  ./dog-breed-identification/train/000bec180eb18...
# 1  ./dog-breed-identification/train/001513dfcb2ff...
# 2  ./dog-breed-identification/train/001cdf01b096e...
# 3  ./dog-breed-identification/train/00214f311d5d2...
# 4  ./dog-breed-identification/train/0021f9ceb3235...

# %%
features = df['filepath']
target = df['breed']

X_train, X_val, Y_train, Y_val = train_test_split(features, target,
                                      test_size=0.15,
                                      random_state=10)

X_train.shape, X_val.shape
# Out:
# ((8688,), (1534,))

# %%
import albumentations as A

transforms_train = A.Compose([
    A.VerticalFlip(p=0.2),
    A.HorizontalFlip(p=0.7),
    A.CoarseDropout(p=0.5),
    A.RandomGamma(p=0.5),
    A.RandomBrightnessContrast(p=1)
])

# %%
img = cv2.imread('./dog-breed-identification/train/00792e341f3c6eb33663e415d0715370.jpg')
plt.imshow(img)
plt.show()

# %%
augments = [A.VerticalFlip(p=1), A.HorizontalFlip(p=1),
            A.CoarseDropout(p=1), A.CLAHE(p=1)]

plt.subplots(figsize=(10, 10))
for i, aug in enumerate(augments):
    plt.subplot(2, 2, i+1)
    aug_img = aug(image=img)['image']
    plt.imshow(aug_img)
plt.show()

# %%
def aug_fn(img):
    aug_data = transforms_train(image=img)
    aug_img = aug_data['image']

    return aug_img


@tf.function
def process_data(img, label):
    aug_img = tf.numpy_function(aug_fn,
                                [img],
                                Tout=tf.float32)

    return img, label


def decode_image(filepath, label=None):

    img = tf.io.read_file(filepath)
    img = tf.image.decode_jpeg(img)
    img = tf.image.resize(img, [128, 128])
    img = tf.cast(img, tf.float32) / 255.0

    if label == None:
        return img

    return img, tf.one_hot(indices=label,
                           depth=120,
                           dtype=tf.float32)

# %%
train_ds = (
    tf.data.Dataset
    .from_tensor_slices((X_train, Y_train))
    .map(decode_image, num_parallel_calls=AUTO)
    .map(partial(process_data), num_parallel_calls=AUTO)
    .batch(32)
    .prefetch(AUTO)
)

val_ds = (
    tf.data.Dataset
    .from_tensor_slices((X_val, Y_val))
    .map(decode_image, num_parallel_calls=AUTO)
    .batch(32)
    .prefetch(AUTO)
)

# %%
for img, label in train_ds.take(1):
  print(img.shape, label.shape)
# Out:
# (32, 128, 128, 3) (32, 120)

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3

pre_trained_model = InceptionV3(
    input_shape=(128, 128, 3),
    weights='imagenet',
    include_top=False
)

# %%
len(pre_trained_model.layers)
# Out:
# 311

# %%
for layer in pre_trained_model.layers: 
  layer.trainable = False

last_layer = pre_trained_model.get_layer('mixed7') 
# Access the output shape from the output tensor of the layer
print('last layer output shape: ', last_layer.output.shape) 
last_output = last_layer.output
# Out:
# last layer output shape:  (None, 6, 6, 768)

# %%
# Model Architecture
x = layers.Flatten()(last_output)
x = layers.Dense(256, activation='relu')(x)
x = layers.BatchNormalization()(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.3)(x)
x = layers.BatchNormalization()(x)
output = layers.Dense(120, activation='softmax')(x)

model = keras.Model(pre_trained_model.input, output)

# Model Compilation
model.compile(
    optimizer='adam',
    loss=keras.losses.CategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.AUC()]
)

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if logs.get('val_auc') is not None and logs.get('val_auc') > 0.99:
            print('\n Validation accuracy has reached upto 90% so, stopping further training.')
            self.model.stop_training = True

es = EarlyStopping(patience=3,
                monitor='val_auc',
                restore_best_weights=True,
                mode='max')

lr = ReduceLROnPlateau(monitor='val_loss',
                    patience=2,
                    factor=0.5,
                    verbose=1)

# %%
history = model.fit(train_ds,
                    validation_data=val_ds,
                    epochs=50,
                    verbose=1,
                    callbacks=[es, lr, myCallback()])
# Out:
# Epoch 1/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 129s 447ms/step - auc: 0.7171 - loss: 4.3423 - val_auc: 0.9334 - val_loss: 2.5938 - learning_rate: 0.0010
# Epoch 2/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 94s 344ms/step - auc: 0.9598 - loss: 2.2492 - val_auc: 0.9408 - val_loss: 2.3480 - learning_rate: 0.0010
# Epoch 3/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 92s 337ms/step - auc: 0.9921 - loss: 1.2048 - val_auc: 0.9233 - val_loss: 2.4608 - learning_rate: 0.0010
# Epoch 4/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - auc: 0.9992 - loss: 0.4922
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 93s 342ms/step - auc: 0.9992 - loss: 0.4919 - val_auc: 0.9115 - val_loss: 2.5696 - learning_rate: 0.0010
# Epoch 5/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 97s 355ms/step - auc: 1.0000 - loss: 0.1688 - val_auc: 0.9232 - val_loss: 2.3589 - learning_rate: 5.0000e-04

# %%
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot()
history_df.loc[:, ['auc', 'val_auc']].plot()
plt.show()

# %%
#-----------------modlel testing-------------------

# %%
def preprocess_image(test_image_path):
    # Read the image
    img = tf.io.read_file(test_image_path)
    # Decode the JPEG image
    img = tf.image.decode_jpeg(img, channels=3)
    # Resize the image to match the model's input shape
    img = tf.image.resize(img, [128, 128])
    # Normalize the image (scale pixel values to [0, 1])
    img = tf.cast(img, tf.float32) / 255.0
    # Add a batch dimension
    img = tf.expand_dims(img, axis=0)
    return img

def predict_image(test_image_path, model, label_encoder):
    # Preprocess the image
    img = preprocess_image(test_image_path)
    # Get model predictions
    prediction = model.predict(img)
    # Get the class with the highest probability
    predicted_class = tf.argmax(prediction, axis=1).numpy()[0]
    # Decode the class label using the LabelEncoder
    predicted_label = label_encoder.inverse_transform([predicted_class])[0]
    return predicted_label

# %%
# Path to a random test image

#test_image_path = './dog-breed-identification/train/00792e341f3c6eb33663e415d0715370.jpg'

#test_image_path = "German-Shepherd.jpg"
#test_image_path = "./random_test_images/Golden-Retriever.jpg"
#test_image_path = "./random_test_images/Shih-Tzu.jpg"
test_image_path = "./random_test_images/Pomeranian.jpg"

# Predict the breed
predicted_breed = predict_image(test_image_path, model, le)
print(f"The predicted breed is: {predicted_breed}")

# Display the test image with the predicted label
img = cv2.imread(test_image_path)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title(f"Predicted Breed: {predicted_breed}")
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# The predicted breed is: french_bulldog

# %%
# Evaluate the model on the validation dataset
loss, auc = model.evaluate(val_ds)

print(f"Validation Loss: {loss}")
print(f"Validation AUC: {auc}")
# Out:
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 17s 302ms/step - auc: 0.9477 - loss: 2.2876
# Validation Loss: 2.3480284214019775
# Validation AUC: 0.9407523274421692
